# %% [markdown]
# # Data Serialization Formats - Cumulative Lab
#
# ## Introduction
#
# Now that you have learned about CSV and JSON file formats individually, it's time to bring them together with a cumulative lab! Even as a junior data scientist, you can often produce novel, interesting analyses by combining multiple datasets that haven't been combined before.
#
# ## Objectives
#
# You will be able to:
#
# * Practice reading serialized JSON and CSV data from files into Python objects
# * Practice extracting information from nested data structures
# * Practice cleaning data (filtering, normalizing locations, converting types)
# * Combine data from multiple sources into a single data structure
# * Interpret descriptive statistics and data visualizations to present your findings
#
# ## Your Task: Analyze the Relationship between Population and World Cup Performance
#
# ![Russia 2018 branded soccer ball and trophy](https://curriculum-content.s3.amazonaws.com/data-science/images/world_cup.jpg)
#
# <span>Photo by <a href="https://unsplash.com/@fznsr_?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Fauzan Saari</a> on <a href="https://unsplash.com/s/photos/soccer-world-cup?utm_source=unsplash&amp;utm_medium=referral&amp;utm_content=creditCopyText">Unsplash</a></span>

# %% [markdown]
# ### Business Understanding
#
# #### What is the relationship between the population of a country and their performance in the 2018 FIFA World Cup?
#
# Intuitively, we might assume that countries with larger populations would have better performance in international sports competitions. While this has been demonstrated to be [true for the Olympics](https://www.researchgate.net/publication/308513557_Medals_at_the_Olympic_Games_The_Relationship_Between_Won_Medals_Gross_Domestic_Product_Population_Size_and_the_Weight_of_Sportive_Practice), the results for the FIFA World Cup are more mixed:
#
# <p><a href="https://web.archive.org/web/20230524202759/https://upload.wikimedia.org/wikipedia/commons/3/3c/World_cup_countries_best_results.png"><img src="https://upload.wikimedia.org/wikipedia/commons/3/3c/World_cup_countries_best_results.png" alt="World cup countries best results and hosts.PNG" height="563" width="1280"></a><br><a href="http://creativecommons.org/licenses/by-sa/3.0/" title="Creative Commons Attribution-Share Alike 3.0">CC BY-SA 3.0</a>, <a href="https://commons.wikimedia.org/w/index.php?curid=578740">Link</a></p>
#
# In this analysis, we are going to look specifically at the sample of World Cup games in 2018 and the corresponding 2018 populations of the participating nations, to determine the relationship between population and World Cup performance for this year.

# %% [markdown]
# ### Data Understanding
#
# The data sources for this analysis will be pulled from two separate files.
#
# #### `world_cup_2018.json`
#
# * **Source**: This dataset comes from [`football.db`](http://openfootball.github.io/), a "free and open public domain football database & schema for use in any (programming) language"
# * **Contents**: Data about all games in the 2018 World Cup, including date, location (city and stadium), teams, goals scored (and by whom), and tournament group
# * **Format**: Nested JSON data (dictionary containing a list of rounds, each of which contains a list of matches, each of which contains information about the teams involved and the points scored)
#
# #### `country_populations.csv`
#
# * **Source**: This dataset comes from a curated collection by [DataHub.io](https://datahub.io/core/population), originally sourced from the World Bank
# * **Contents**: Data about populations by country for all available years from 1960 to 2018
# * **Format**: CSV data, where each row contains a country name, a year, and a population

# %% [markdown]
# ### Requirements
#
# #### 1. List of Teams in 2018 World Cup
#
# Create an alphabetically-sorted list of teams who competed in the 2018 FIFA World Cup.
#
# #### 2. Associating Countries with 2018 World Cup Performance
#
# Create a data structure that connects a team name (country name) to its performance in the 2018 FIFA World Cup. We'll use the count of games won in the entire tournament (group stage as well as knockout stage) to represent the performance.
#
# This will help create visualizations to help the reader understand the distribution of games won and the performance of each team.
#
# #### 3. Associating Countries with 2018 Population
#
# Add to the existing data structure so that it also connects each country name to its 2018 population, and create visualizations comparable to those from step 2.
#
# #### 4. Analysis of Population vs. Performance
#
# Choose an appropriate statistical measure to analyze the relationship between population and performance, and create a visualization representing this relationship.

# %% [markdown]
# ### Checking for Understanding
#
# Before moving on to the next step, pause and think about the strategy for this analysis.
#
# Remember, our business question is:
#
# > What is the relationship between the population of a country and their performance in the 2018 FIFA World Cup?
#
# #### Unit of Analysis
#
# First, what is our **unit of analysis**, and what is the **unique identifier**? In other words, what will one record in our final data structure represent, and what attribute uniquely describes it?
#
# .
#
# .
#
# .
#
# *Answer:*
#
# > What is the relationship between the population of a **country** and their performance in the 2018 FIFA World Cup?
#
# *Our unit of analysis is a* ***country*** *and the unique identifier we'll use is the* ***country name***
#
# #### Features
#
# Next, what **features** are we analyzing? In other words, what attributes of each country are we interested in?
#
# .
#
# .
#
# .
#
# *Answer:*
#
# > What is the relationship between the **population** of a country and their **performance in the 2018 FIFA World Cup**?
#
# *Our features are* ***2018 population*** *and* ***count of wins in the 2018 World Cup***
#
# #### Dataset to Start With
#
# Finally, which dataset should we **start** with? In this case, any record with missing data is not useful to us, so we want to start with the smaller dataset.
#
# .
#
# .
#
# .
#
# *Answer: There are only 32 countries that compete in the World Cup each year, compared to hundreds of countries in the world, so we should start with the* ***2018 World Cup*** *dataset. Then we can join it with the relevant records from the country population dataset.*

# %% [markdown]
# ## Getting the Data
#
# Below we import the `json` and `csv` modules, which will be used for reading from `world_cup_2018.json` and `country_populations.csv`, respectively.

# %%
# Run this cell without changes
import json
import csv

# %% [markdown]
# Next, we open the relevant files.

# %%
# Run this cell without changes
world_cup_file = open("data/world_cup_2018.json", encoding="utf8")
population_file = open("data/country_populations.csv")

# %% [markdown]
# **Hint:** if your code below is not working, (e.g. `ValueError: I/O operation on closed file.`, or you get an empty list or dictionary) try re-running the cell above to reopen the files, then re-run your code.
#
# ### 2018 World Cup Data
#
# In the cell below, use the `json` module to load the data from `world_cup_file` into a dictionary called `world_cup_data`

# %%
# Replace None with appropriate code
world_cup_data = json.load(world_cup_file)

# Close the file now that we're done reading from it
world_cup_file.close()

# %% [markdown]
# Make sure the `assert` passes, ensuring that `world_cup_data` has the correct type.

# %%
# Run this cell without changes

# Check that the overall data structure is a dictionary
assert type(world_cup_data) == dict

# Check that the dictionary has 2 keys, 'name' and 'rounds'
assert list(world_cup_data.keys()) == ["name", "rounds"]

# %% [markdown]
# ### Population Data
#
# Now use the `csv` module to load the data from `population_file` into a list of dictionaries called `population_data`
#
# (Recall that you can convert a `csv.DictReader` object into a list of dictionaries using the built-in `list()` function.)

# %%
# Replace None with appropriate code
reader = csv.DictReader(population_file)
population_data = list(reader)

# Close the file now that we're done reading from it
population_file.close()

# %% [markdown]
# Make sure the `assert`s pass, ensuring that `population_data` has the correct type.

# %%
# Run this cell without changes

# Check that the overall data structure is a list
assert type(population_data) == list

# Check that the 0th element is a dictionary
# (csv.DictReader interface differs slightly by Python version;
# either a dict or an OrderedDict is fine here)
from collections import OrderedDict

assert type(population_data[0]) == dict or type(population_data[0]) == OrderedDict

# %% [markdown]
# ## 1. List of Teams in 2018 World Cup
#
# > Create an alphabetically-sorted list of teams who competed in the 2018 FIFA World Cup.
#
# This will take several steps, some of which have been completed for you.
#
# ### Exploring the Structure of the World Cup Data JSON
#
# Let's start by exploring the structure of `world_cup_data`. Here is a pretty-printed preview of its contents:
#
# ```
# {
#   "name": "World Cup 2018",
#   "rounds": [
#     {
#       "name": "Matchday 1",
#       "matches": [
#         {
#           "num": 1,
#           "date": "2018-06-14",
#           "time": "18:00",
#           "team1": { "name": "Russia",       "code": "RUS" },
#           "team2": { "name": "Saudi Arabia", "code": "KSA" },
#           "score1":  5,
#           "score2":  0,
#           "score1i": 2,
#           "score2i": 0,
#           "goals1": [
#             { "name": "Gazinsky",   "minute": 12,              "score1": 1, "score2": 0 },
#             { "name": "Cheryshev",  "minute": 43,              "score1": 2, "score2": 0 },
#             { "name": "Dzyuba",     "minute": 71,              "score1": 3, "score2": 0 },
#             { "name": "Cheryshev",  "minute": 90, "offset": 1, "score1": 4, "score2": 0 },
#             { "name": "Golovin",    "minute": 90, "offset": 4, "score1": 5, "score2": 0 }
#           ],
#           "goals2": [],
#           "group": "Group A",
#           "stadium": { "key": "luzhniki", "name": "Luzhniki Stadium" },
#           "city": "Moscow",
#           "timezone": "UTC+3"
#         }
#       ]
#     },
#     {
#       "name": "Matchday 2",
#       "matches": [
#         {
#           "num": 2,
#           "date": "2018-06-15",
#           "time": "17:00",
#           "team1": { "name": "Egypt",   "code": "EGY" },
#           "team2": { "name": "Uruguay", "code": "URU" },
#           "score1":  0,
#           "score2":  1,
#           "score1i": 0,
#           "score2i": 0,
#           "goals1": [],
#           "goals2": [
#             { "name": "Giménez",  "minute": 89,  "score1": 0, "score2": 1 }
#           ],
#           "group": "Group A",
#           "stadium": { "key": "ekaterinburg", "name": "Ekaterinburg Arena" },
#           "city": "Ekaterinburg",
#           "timezone": "UTC+5"
#         },
#         ...
#       ],
#     },
#   ],
# }
# ```
#
# As noted previously, `world_cup_data` is a dictionary with two keys, 'name' and 'rounds'.

# %%
# Run this cell without changes
world_cup_data.keys()
# Out:
# dict_keys(['name', 'rounds'])

# %% [markdown]
# The value associated with the 'name' key is simply identifying the dataset.

# %%
# Run this cell without changes
world_cup_data["name"]
# Out:
# 'World Cup 2018'

# %% [markdown]
# ### Extracting Rounds
#
# The value associated with the 'rounds' key is a list containing all of the actual information about the rounds and the matches within those rounds.

# %%
# Run this cell without changes
rounds = world_cup_data["rounds"]

print("type(rounds):", type(rounds))
print("len(rounds):", len(rounds))
print("type(rounds[3])", type(rounds[3]))
print("rounds[3]:")
rounds[3]
# Out:
# type(rounds): <class 'list'>
# len(rounds): 20
# type(rounds[3]) <class 'dict'>
# rounds[3]:
# {'name': 'Matchday 4',
#  'matches': [{'num': 9,
#    'date': '2018-06-17',
#    'time': '21:00',
#    'team1': {'name': 'Brazil', 'code': 'BRA'},
#    'team2': {'name': 'Switzerland', 'code': 'SUI'},
#    'score1': 1,
#    'score2': 1,
#    'score1i': 1,
#    'score2i': 0,
#    'goals1': [{'name': 'Coutinho', 'minute': 20, 'score1': 1, 'score2': 0}],
#    'goals2': [{'name': 'Zuber', 'minute': 50, 'score1': 1, 'score2': 1}],
#    'group': 'Group E',
#    'stadium': {'key': 'rostov', 'name': 'Rostov Arena'},
#    'city': 'Rostov-on-Don',
#    'timezone': 'UTC+3'},
#   {'num': 10,
#    'date': '2018-06-17',
#    'time': '16:00',
#    'team1': {'name': 'Costa Rica', 'code': 'CRC'},
#    'team2': {'name': 'Serbia', 'code': 'SRB'},
#    'score1': 0,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 0,
#    'goals1': [],
#    'goals2': [{'name': 'Kolarov', 'minute': 56, 'score1': 0, 'score2': 1}],
#    'group': 'Group E',
#    'stadium': {'key': 'samara', 'name': 'Samara Arena'},
#    'city': 'Samara',
#    'timezone': 'UTC+4'},
#   {'num': 11,
#    'date': '2018-06-17',
#    'time': '18:00',
#    'team1': {'name': 'Germany', 'code': 'GER'},
#    'team2': {'name': 'Mexico', 'code': 'MEX'},
#    'score1': 0,
#    'score2': 1,
#    'score1i': 0,
#    'score2i': 1,
#    'goals1': [],
#    'goals2': [{'name': 'Lozano', 'minute': 35, 'score1': 0, 'score2': 1}],
#    'group': 'Group F',
#    'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#    'city': 'Moscow',
#    'timezone': 'UTC+3'}]}

# %% [markdown]
# Translating this output into English:
#
# Starting with the original `world_cup_data` dictionary, we used the key `"rounds"` to extract a list of rounds, which we assigned to the variable `rounds`.
#
# `rounds` is a list of dictionaries. Each dictionary inside of `rounds` contains a name (e.g. `"Matchday 4"`) as well as a list of matches.

# %% [markdown]
# ### Extracting Matches
#
# Now we can go one level deeper and extract all of the matches in the tournament. Because the round is irrelevant for this analysis, we can loop over all rounds and combine all of their matches into a single list.
#
# **Hint:** This is a good use case for using the `.extend` list method rather than `.append`, since we want to combine several lists of dictionaries into a single list of dictionaries, not a list of lists of dictionaries. [Documentation here.](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists)

# %%
# Replace None with appropriate code
matches = []

# "round" is a built-in function in Python so we use "round_" instead
for round_ in rounds:
    # Extract the list of matches for this round
    round_matches = round_['matches']
    # Add them to the overall list of matches
    matches.extend(round_matches)

matches[0]
# Out:
# {'num': 1,
#  'date': '2018-06-14',
#  'time': '18:00',
#  'team1': {'name': 'Russia', 'code': 'RUS'},
#  'team2': {'name': 'Saudi Arabia', 'code': 'KSA'},
#  'score1': 5,
#  'score2': 0,
#  'score1i': 2,
#  'score2i': 0,
#  'goals1': [{'name': 'Gazinsky', 'minute': 12, 'score1': 1, 'score2': 0},
#   {'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0},
#   {'name': 'Dzyuba', 'minute': 71, 'score1': 3, 'score2': 0},
#   {'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0},
#   {'name': 'Golovin', 'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0}],
#  'goals2': [],
#  'group': 'Group A',
#  'stadium': {'key': 'luzhniki', 'name': 'Luzhniki Stadium'},
#  'city': 'Moscow',
#  'timezone': 'UTC+3'}

# %% [markdown]
# Make sure the `assert`s pass before moving on to the next step.

# %%
# Run this cell without changes

# There should be 64 matches. If the length is 20, that means
# you have a list of lists instead of a list of dictionaries
assert len(matches) == 64

# Each match in the list should be a dictionary
assert type(matches[0]) == dict

# %% [markdown]
# ### Extracting Teams
#
# Each match has a `team1` and a `team2`.

# %%
# Run this cell without changes
print(matches[0]["team1"])
print(matches[0]["team2"])
# Out:
# {'name': 'Russia', 'code': 'RUS'}
# {'name': 'Saudi Arabia', 'code': 'KSA'}

# %% [markdown]
# Create a list of all unique team names by looping over every match in `matches` and adding the `"name"` values associated with both `team1` and `team2`. (Same as before when creating a list of matches, it doesn't matter right now whether a given team was "team1" or "team2", we just add everything to `teams`.)
#
# We'll use a `set` data type ([documentation here](https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset)) to ensure unique teams, then convert it to a sorted list at the end.

# %%
# Replace None with appropriate code
teams_set = set()

for match in matches:
    # Add team1 name value to teams_set
    teams_set.add(match["team1"]["name"])
    # Add team2 name value to teams_set
    teams_set.add(match["team2"]["name"])

teams = sorted(list(teams_set))
print(teams)
# Out:
# ['Argentina', 'Australia', 'Belgium', 'Brazil', 'Colombia', 'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England', 'France', 'Germany', 'Iceland', 'Iran', 'Japan', 'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru', 'Poland', 'Portugal', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Tunisia', 'Uruguay']

# %% [markdown]
# Make sure the `assert`s pass before moving on to the next step.

# %%
# Run this cell without changes

# teams should be a list, not a set
assert type(teams) == list

# 32 teams competed in the 2018 World Cup
assert len(teams) == 32

# Each element of teams should be a string
# (the name), not a dictionary
assert type(teams[0]) == str

# %% [markdown]
# Step 1 complete. We have unique identifiers (names) for each of our records (countries) that we will be able to use to connect 2018 World Cup performance to 2018 population.

# %% [markdown]
# ## 2. Associating Countries with 2018 World Cup Performance
#
# > Create a data structure that connects a team name (country name) to its performance in the 2018 FIFA World Cup. We'll use the count of games won in the entire tournament (group stage as well as knockout stage) to represent the performance.
#
# > Also, create visualizations to help the reader understand the distribution of games won and the performance of each team.
#
# So, we are building a **data structure** that connects a country name to the number of wins. There is no universal correct format for a data structure with this purpose, but we are going to use a format that resembles the "dataframe" format that will be introduced later in the course.
#
# Specifically, we'll build a **dictionary** where each key is the name of a country, and each value is a nested dictionary containing information about the number of wins and the 2018 population.
#
# The final result will look something like this:
# ```
# {
#   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
#   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# }
# ```
#
# For the current step (step 2), we'll build a data structure that looks something like this:
# ```
# {
#   'Argentina': { 'wins': 1 },
#   ...
#   'Uruguay':   { 'wins': 4 }
# }
# ```
#
# ### Initializing with Wins Set to Zero
#
# Start by initializing a dictionary called `combined_data` containing:
#
# * Keys: the strings from `teams`
# * Values: each value the same, a dictionary containing the key `'wins'` with the associated value `0`. However, note that each value should be a distinct dictionary object in memory, not the same dictionary linked as a value in multiple places.
#
# Initially `combined_data` will look something like this:
# ```
# {
#   'Argentina': { 'wins': 0 },
#   ...
#   'Uruguay':   { 'wins': 0 }
# }
# ```

# %%
# Replace None with appropriate code

# Create the variable combined_data as described above
combined_data = {team: {'wins': 0} for team in teams}
print(combined_data)
# Out:
# {'Argentina': {'wins': 0}, 'Australia': {'wins': 0}, 'Belgium': {'wins': 0}, 'Brazil': {'wins': 0}, 'Colombia': {'wins': 0}, 'Costa Rica': {'wins': 0}, 'Croatia': {'wins': 0}, 'Denmark': {'wins': 0}, 'Egypt': {'wins': 0}, 'England': {'wins': 0}, 'France': {'wins': 0}, 'Germany': {'wins': 0}, 'Iceland': {'wins': 0}, 'Iran': {'wins': 0}, 'Japan': {'wins': 0}, 'Mexico': {'wins': 0}, 'Morocco': {'wins': 0}, 'Nigeria': {'wins': 0}, 'Panama': {'wins': 0}, 'Peru': {'wins': 0}, 'Poland': {'wins': 0}, 'Portugal': {'wins': 0}, 'Russia': {'wins': 0}, 'Saudi Arabia': {'wins': 0}, 'Senegal': {'wins': 0}, 'Serbia': {'wins': 0}, 'South Korea': {'wins': 0}, 'Spain': {'wins': 0}, 'Sweden': {'wins': 0}, 'Switzerland': {'wins': 0}, 'Tunisia': {'wins': 0}, 'Uruguay': {'wins': 0}}

# %% [markdown]
# Check that the `assert`s pass.

# %%
# Run this cell without changes

# combined_data should be a dictionary
assert type(combined_data) == dict

# the keys should be strings
assert type(list(combined_data.keys())[0]) == str

# the values should be dictionaries
assert combined_data["Japan"] == {"wins": 0}

# %% [markdown]
# ### Adding Wins from Matches
#
# Now it's time to revisit the `matches` list from earlier, in order to associate a team with the number of times it has won a match.
#
# This time, let's write some functions to help organize our logic.
#
# Write a function `find_winner` that takes in a `match` dictionary, and returns the name of the team that won the match.  Recall that a match is structured like this:
#
# ```
# {
#   'num': 1,
#   'date': '2018-06-14',
#   'time': '18:00',
#   'team1': { 'name': 'Russia',       'code': 'RUS' },
#   'team2': { 'name': 'Saudi Arabia', 'code': 'KSA' },
#   'score1': 5,
#   'score2': 0,
#   'score1i': 2,
#   'score2i': 0,
#   'goals1': [
#     { 'name': 'Gazinsky',  'minute': 12, 'score1': 1, 'score2': 0 },
#     { 'name': 'Cheryshev', 'minute': 43, 'score1': 2, 'score2': 0 },
#     { 'name': 'Dzyuba',    'minute': 71, 'score1': 3, 'score2': 0 },
#     { 'name': 'Cheryshev', 'minute': 90, 'offset': 1, 'score1': 4, 'score2': 0 },
#     { 'name': 'Golovin',   'minute': 90, 'offset': 4, 'score1': 5, 'score2': 0 }
#   ],
#   'goals2': [],
#   'group': 'Group A',
#   'stadium': { 'key': 'luzhniki', 'name': 'Luzhniki Stadium' },
#   'city': 'Moscow',
#   'timezone': 'UTC+3'
# }
# ```
#
# The winner is determined by comparing the values associated with the `'score1'` and `'score2'` keys. If score 1 is larger, then the name associated with the `'team1'` key is the winner. If score 2 is larger, then the name associated with the `'team2'` key is the winner. If the values are the same, there is no winner, so return `None`. (Unlike the group round of the World Cup, we are only counting *wins* as our "performance" construct, not 3 points for a win and 1 point for a tie.)

# %%
# Replace None with appropriate code


def find_winner(match):
    """
    Given a dictionary containing information about a match,
    return the name of the winner (or None in the case of a tie)
    """
    if match['score1'] > match['score2']:
        return match['team1']['name']
    elif match['score2'] > match['score1']:
        return match['team2']['name']
    else:
        return None

# %%
# Run this cell without changes
assert find_winner(matches[0]) == "Russia"
assert find_winner(matches[1]) == "Uruguay"
assert find_winner(matches[2]) == None

# %% [markdown]
# Now that we have this helper function, loop over every match in `matches`, find the winner, and add 1 to the associated count of wins in `combined_data`. If the winner is `None`, skip adding it to the dictionary.

# %%
# Replace None with appropriate code

combined_data = {}

for match in matches:
    # Get the name of the winner
    winner = find_winner(match)
    # Only proceed to the next step if there was
    # a winner
    if winner:
        # Add 1 to the associated count of wins
        if winner in combined_data:
            combined_data[winner]["wins"] += 1
        else:
            combined_data[winner] = {"wins": 1}

# Visually inspect the output to ensure the wins are
# different for different countries
combined_data
# Out:
# {'Russia': {'wins': 2},
#  'Uruguay': {'wins': 4},
#  'Iran': {'wins': 1},
#  'France': {'wins': 6},
#  'Denmark': {'wins': 1},
#  'Croatia': {'wins': 3},
#  'Serbia': {'wins': 1},
#  'Mexico': {'wins': 2},
#  'Sweden': {'wins': 3},
#  'Belgium': {'wins': 6},
#  'England': {'wins': 3},
#  'Senegal': {'wins': 1},
#  'Japan': {'wins': 1},
#  'Portugal': {'wins': 1},
#  'Spain': {'wins': 1},
#  'Nigeria': {'wins': 1},
#  'Brazil': {'wins': 3},
#  'Switzerland': {'wins': 1},
#  'Germany': {'wins': 1},
#  'Colombia': {'wins': 2},
#  'Saudi Arabia': {'wins': 1},
#  'Peru': {'wins': 1},
#  'Argentina': {'wins': 1},
#  'South Korea': {'wins': 1},
#  'Tunisia': {'wins': 1},
#  'Poland': {'wins': 1}}

# %% [markdown]
# ### Analysis of Wins
#
# While we could try to understand all 32 of those numbers just by scanning through them, let's use some descriptive statistics and data visualizations instead
#
# #### Statistical Summary of Wins
#
# The code below calculates the mean, median, and standard deviation of the number of wins. If it doesn't work, that is an indication that something went wrong with the creation of the `combined_data` variable, and you might want to look at the solution branch and fix your code before proceeding.

# %%
# Run this cell without changes
import numpy as np

teams = list(combined_data.keys())
wins = [val["wins"] for val in combined_data.values()]


print("Mean number of wins:", np.mean(wins))
print("Median number of wins:", np.median(wins))
print("Standard deviation of number of wins:", np.std(wins))
# Out:
# Mean number of wins: 1.9230769230769231
# Median number of wins: 1.0
# Standard deviation of number of wins: 1.4655814525582809

# %% [markdown]
# #### Visualizations of Wins
#
# In addition to those numbers, let's make a histogram (showing the distributions of the number of wins) and a bar graph (showing the number of wins by country).

# %%
# Run this cell without changes
import matplotlib.pyplot as plt

# Set up figure and axes
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 7))
fig.set_tight_layout(True)

# Histogram of Wins and Frequencies
ax1.hist(x=wins, bins=range(8), align="left", color="green")
ax1.set_xticks(range(7))
ax1.set_xlabel("Wins in 2018 World Cup")
ax1.set_ylabel("Frequency")
ax1.set_title("Distribution of Wins")

# Horizontal Bar Graph of Wins by Country
ax2.barh(teams[::-1], wins[::-1], color="green")
ax2.set_xlabel("Wins in 2018 World Cup")
ax2.set_title("Wins by Country");

# %% [markdown]
# #### Interpretation of Win Analysis
#
# Before we move to looking at the relationship between wins and population, it's useful to understand the distribution of wins alone. A few notes of interpretation:
#
# * The number of wins is skewed and looks like a [negative binomial distribution](https://en.wikipedia.org/wiki/Negative_binomial_distribution), which makes sense conceptually
# * The "typical" value here is 1 (both the median and the highest point of the histogram), meaning a typical team that qualifies for the World Cup wins once
# * There are a few teams we might consider outliers: Belgium and France, with 6x the wins of the "typical" team and 1.5x the wins of the next "runner-up" (Uruguay, with 4 wins)
# * This is a fairly small dataset, something that becomes more noticeable with such a "spiky" (not smooth) histogram

# %% [markdown]
# ## 3. Associating Countries with 2018 Population
#
# > Add to the existing data structure so that it also connects each country name to its 2018 population, and create visualizations comparable to those from step 2.
#
# Now we're ready to add the 2018 population to `combined_data`, finally using the CSV file
#
# Recall that `combined_data` currently looks something like this:
# ```
# {
#   'Argentina': { 'wins': 1 },
#   ...
#   'Uruguay':   { 'wins': 4 }
# }
# ```
#
# And the goal is for it to look something like this:
# ```
# {
#   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
#   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# }
# ```
#
# To do that, we need to extract the 2018 population information from the CSV data.
#
# ### Exploring the Structure of the Population Data CSV
#
# Recall that previously we loaded information from a CSV containing population data into a list of dictionaries called `population_data`.

# %%
# Run this cell without changes
len(population_data)
# Out:
# 12695

# %% [markdown]
# 12,695 is a very large number of rows to print out, so let's look at some samples instead.

# %%
# Run this cell without changes
np.random.seed(42)
population_record_samples = np.random.choice(population_data, size=10)
population_record_samples
# Out:
# array([{'': '9984', 'Country Name': 'Malta', 'Country Code': 'MLT', 'Year': '1983', 'Value': '330524'},
#        {'': '3574', 'Country Name': 'Bahrain', 'Country Code': 'BHR', 'Year': '1994', 'Value': '549583'},
#        {'': '8104', 'Country Name': 'Iran, Islamic Rep.', 'Country Code': 'IRN', 'Year': '1988', 'Value': '53077313'},
#        {'': '7905', 'Country Name': 'Iceland', 'Country Code': 'ISL', 'Year': '1966', 'Value': '195570'},
#        {'': '14678', 'Country Name': 'United Arab Emirates', 'Country Code': 'ARE', 'Year': '1966', 'Value': '159976'},
#        {'': '13998', 'Country Name': 'Thailand', 'Country Code': 'THA', 'Year': '1994', 'Value': '58875269'},
#        {'': '8448', 'Country Name': 'Jamaica', 'Country Code': 'JAM', 'Year': '1978', 'Value': '2105907'},
#        {'': '8979', 'Country Name': 'Kuwait', 'Country Code': 'KWT', 'Year': '1978', 'Value': '1224067'},
#        {'': '3180', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2013', 'Value': '42202935'},
#        {'': '7140', 'Country Name': 'Gibraltar', 'Country Code': 'GIB', 'Year': '1968', 'Value': '27685'}],
#       dtype=object)

# %% [markdown]
# There are **2 filtering tasks**, **1 data normalization task**, and **1 type conversion task** to be completed, based on what we can see in this sample. We'll walk through each of them below.
#
# (In a more realistic data cleaning environment, you most likely won't happen to get a sample that demonstrates all of the data cleaning steps needed, but this sample was chosen carefully for example purposes.)
#
# ### Filtering Population Data
#
# We already should have suspected that this dataset would require some filtering, since there are 32 records in our current `combined_data` dataset and 12,695 records in `population_data`. Now that we have looked at this sample, we can identify 2 features we'll want to use in order to filter down the `population_data` records to just 32. Try to identify them before looking at the answer below.
#
# .
#
# .
#
# .
#
# *Answer: the two features to filter on are* ***`'Country Name'`*** *and* ***`'Year'`***. *We can see from the sample above that there are countries in `population_data` that are not present in `combined_data` (e.g. Malta) and there are years present that are not 2018.*
#
# In the cell below, create a new variable `population_data_filtered` that only includes relevant records from `population_data`. Relevant records are records where the country name is one of the countries in the `teams` list, and the year is "2018".
#
# (It's okay to leave 2018 as a string since we are not performing any math operations on it, just make sure you check for `"2018"` and not `2018`.)

# %%
# Replace None with appropriate code

population_data_filtered = []

for record in population_data:
    # Add record to population_data_filtered if relevant
    if record['Country Name'] in combined_data and record['Year'] == "2018":
        # Add record to population_data_filtered
        population_data_filtered.append(record)

len(population_data_filtered)  # 27
# Out:
# 22

# %% [markdown]
# Hmm...what went wrong? Why do we only have 27 records, and not 32?
#
# Did we really get a dataset with 12k records that's missing 5 of the data points we need?
#
# Let's take a closer look at the population data samples again, specifically the third one:

# %%
# Run this cell without changes
population_record_samples[2]
# Out:
# {'': '8104',
#  'Country Name': 'Iran, Islamic Rep.',
#  'Country Code': 'IRN',
#  'Year': '1988',
#  'Value': '53077313'}

# %% [markdown]
# And compare that with the value for Iran in `teams`:

# %%
# Run this cell without changes
teams[13]
# Out:
# 'Portugal'

# %% [markdown]
# Ohhhh...we have a data normalization issue. One dataset refers to this country as `'Iran, Islamic Rep.'`, while the other refers to it as `'Iran'`. This is a common issue we face when using data about countries and regions, where there is no universally-accepted naming convention.
#
# ### Normalizing Locations in Population Data
#
# Sometimes data normalization can be a very, very time-consuming task where you need to find "crosswalk" data that can link the two formats together, or you need to write advanced regex formulas to line everything up.
#
# For this task, there are only 5 missing, so we'll just go ahead and give you a function that makes the appropriate substitutions.

# %%
# Run this cell without changes
def normalize_location(country_name):
    """
    Given a country name, return the name that the
    country uses when playing in the FIFA World Cup
    """
    name_sub_dict = {
        "Russian Federation": "Russia",
        "Egypt, Arab Rep.": "Egypt",
        "Iran, Islamic Rep.": "Iran",
        "Korea, Rep.": "South Korea",
        "United Kingdom": "England",
    }
    # The .get method returns the corresponding value from
    # the dict if present, otherwise returns country_name
    return name_sub_dict.get(country_name, country_name)


# Example where normalized location is different
print(normalize_location("Russian Federation"))
# Example where normalized location is the same
print(normalize_location("Argentina"))
# Out:
# Russia
# Argentina

# %% [markdown]
# Now, write new code to create `population_data_filtered` with normalized country names.

# %%
print(population_data[0])  # Print the first record to inspect its structure
# Out:
# {'': '2714', 'Country Name': 'Afghanistan', 'Country Code': 'AFG', 'Year': '1960', 'Value': '8996973'}

# %%
# Replace None with appropriate code

population_data_filtered = []

for record in population_data:
    # Get normalized country name
    normalized_country = normalize_location(record['Country Name']) 
    
    # Add record to population_data_filtered if relevant
    if normalized_country in combined_data:
        # Replace the country name in the record
        record['Country Name'] = normalized_country  # Update the key accordingly
        # Append to list
        population_data_filtered.append(record)

# Check the length to ensure 32 records are selected
print(len(population_data_filtered))  # 32
# Out:
# 1504

# %% [markdown]
# Great, now we should have 32 records instead of 27.
#
# ### Type Conversion of Population Data
#
# We need to do one more thing before we'll have population data that is usable for analysis. Take a look at this record from `population_data_filtered` to see if you can spot it:

# %%
# Run this cell without changes
population_data_filtered[0]
# Out:
# {'': '3127',
#  'Country Name': 'Argentina',
#  'Country Code': 'ARG',
#  'Year': '1960',
#  'Value': '20481779'}

# %% [markdown]
# Every key has the same data type (`str`), including the population value. In this example, it's `'44494502'`, when it needs to be `44494502` if we want to be able to compute statistics with it.
#
# In the cell below, loop over `population_data_filtered` and convert the data type of the value associated with the `"Value"` key from a string to an integer, using the built-in `int()` function.

# %%
# Replace None with appropriate code
for record in population_data_filtered:
    # Convert the population value from str to int
    print(record)
    record['Value'] = int(record['Value'])

# Look at the last record to make sure the population
# value is an int
population_data_filtered[-1]
# Out:
# {'': '3127', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1960', 'Value': '20481779'}
# {'': '3128', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1961', 'Value': '20817266'}
# {'': '3129', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1962', 'Value': '21153052'}
# {'': '3130', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1963', 'Value': '21488912'}
# {'': '3131', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1964', 'Value': '21824425'}
# {'': '3132', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1965', 'Value': '22159650'}
# {'': '3133', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1966', 'Value': '22494035'}
# {'': '3134', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1967', 'Value': '22828869'}
# {'': '3135', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1968', 'Value': '23168267'}
# {'': '3136', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1969', 'Value': '23517611'}
# {'': '3137', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1970', 'Value': '23880561'}
# {'': '3138', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1971', 'Value': '24259561'}
# {'': '3139', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1972', 'Value': '24653175'}
# {'': '3140', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1973', 'Value': '25056478'}
# {'': '3141', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1974', 'Value': '25462302'}
# {'': '3142', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1975', 'Value': '25865776'}
# {'': '3143', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1976', 'Value': '26264681'}
# {'': '3144', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1977', 'Value': '26661398'}
# {'': '3145', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1978', 'Value': '27061047'}
# {'': '3146', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1979', 'Value': '27471036'}
# {'': '3147', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1980', 'Value': '27896528'}
# {'': '3148', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1981', 'Value': '28338515'}
# {'': '3149', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1982', 'Value': '28794548'}
# {'': '3150', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1983', 'Value': '29262047'}
# {'': '3151', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1984', 'Value': '29737093'}
# {'': '3152', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1985', 'Value': '30216279'}
# {'': '3153', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1986', 'Value': '30698964'}
# {'': '3154', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1987', 'Value': '31184415'}
# {'': '3155', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1988', 'Value': '31668949'}
# {'': '3156', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1989', 'Value': '32148134'}
# {'': '3157', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1990', 'Value': '32618651'}
# {'': '3158', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1991', 'Value': '33079000'}
# {'': '3159', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1992', 'Value': '33529326'}
# {'': '3160', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1993', 'Value': '33970111'}
# {'': '3161', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1994', 'Value': '34402672'}
# {'': '3162', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1995', 'Value': '34828170'}
# {'': '3163', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1996', 'Value': '35246374'}
# {'': '3164', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1997', 'Value': '35657429'}
# {'': '3165', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1998', 'Value': '36063459'}
# {'': '3166', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '1999', 'Value': '36467218'}
# {'': '3167', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2000', 'Value': '36870787'}
# {'': '3168', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2001', 'Value': '37275652'}
# {'': '3169', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2002', 'Value': '37681749'}
# {'': '3170', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2003', 'Value': '38087868'}
# {'': '3171', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2004', 'Value': '38491972'}
# {'': '3172', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2005', 'Value': '38892931'}
# {'': '3173', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2006', 'Value': '39289878'}
# {'': '3174', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2007', 'Value': '39684295'}
# {'': '3175', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2008', 'Value': '40080160'}
# {'': '3176', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2009', 'Value': '40482788'}
# {'': '3177', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2010', 'Value': '40788453'}
# {'': '3178', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2011', 'Value': '41261490'}
# {'': '3179', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2012', 'Value': '41733271'}
# {'': '3180', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2013', 'Value': '42202935'}
# {'': '3181', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2014', 'Value': '42669500'}
# {'': '3182', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2015', 'Value': '43131966'}
# {'': '3183', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2016', 'Value': '43590368'}
# {'': '3184', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2017', 'Value': '44044811'}
# {'': '3185', 'Country Name': 'Argentina', 'Country Code': 'ARG', 'Year': '2018', 'Value': '44494502'}
# {'': '3776', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1960', 'Value': '9153489'}
# {'': '3777', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1961', 'Value': '9183948'}
# {'': '3778', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1962', 'Value': '9220578'}
# {'': '3779', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1963', 'Value': '9289770'}
# {'': '3780', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1964', 'Value': '9378113'}
# {'': '3781', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1965', 'Value': '9463667'}
# {'': '3782', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1966', 'Value': '9527807'}
# {'': '3783', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1967', 'Value': '9580991'}
# {'': '3784', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1968', 'Value': '9618756'}
# {'': '3785', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1969', 'Value': '9646032'}
# {'': '3786', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1970', 'Value': '9655549'}
# {'': '3787', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1971', 'Value': '9673162'}
# {'': '3788', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1972', 'Value': '9711115'}
# {'': '3789', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1973', 'Value': '9741720'}
# {'': '3790', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1974', 'Value': '9772419'}
# {'': '3791', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1975', 'Value': '9800700'}
# {'': '3792', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1976', 'Value': '9818227'}
# {'': '3793', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1977', 'Value': '9830358'}
# {'': '3794', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1978', 'Value': '9839534'}
# {'': '3795', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1979', 'Value': '9848382'}
# {'': '3796', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1980', 'Value': '9859242'}
# {'': '3797', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1981', 'Value': '9858982'}
# {'': '3798', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1982', 'Value': '9856303'}
# {'': '3799', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1983', 'Value': '9855520'}
# {'': '3800', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1984', 'Value': '9855372'}
# {'': '3801', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1985', 'Value': '9858308'}
# {'': '3802', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1986', 'Value': '9861823'}
# {'': '3803', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1987', 'Value': '9870234'}
# {'': '3804', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1988', 'Value': '9901664'}
# {'': '3805', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1989', 'Value': '9937697'}
# {'': '3806', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1990', 'Value': '9967379'}
# {'': '3807', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1991', 'Value': '10004486'}
# {'': '3808', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1992', 'Value': '10045158'}
# {'': '3809', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1993', 'Value': '10084475'}
# {'': '3810', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1994', 'Value': '10115603'}
# {'': '3811', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1995', 'Value': '10136811'}
# {'': '3812', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1996', 'Value': '10156637'}
# {'': '3813', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1997', 'Value': '10181245'}
# {'': '3814', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1998', 'Value': '10203008'}
# {'': '3815', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '1999', 'Value': '10226419'}
# {'': '3816', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2000', 'Value': '10251250'}
# {'': '3817', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2001', 'Value': '10286570'}
# {'': '3818', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2002', 'Value': '10332785'}
# {'': '3819', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2003', 'Value': '10376133'}
# {'': '3820', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2004', 'Value': '10421137'}
# {'': '3821', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2005', 'Value': '10478617'}
# {'': '3822', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2006', 'Value': '10547958'}
# {'': '3823', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2007', 'Value': '10625700'}
# {'': '3824', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2008', 'Value': '10709973'}
# {'': '3825', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2009', 'Value': '10796493'}
# {'': '3826', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2010', 'Value': '10895586'}
# {'': '3827', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2011', 'Value': '11038264'}
# {'': '3828', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2012', 'Value': '11106932'}
# {'': '3829', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2013', 'Value': '11159407'}
# {'': '3830', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2014', 'Value': '11209057'}
# {'': '3831', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2015', 'Value': '11274196'}
# {'': '3832', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2016', 'Value': '11331422'}
# {'': '3833', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2017', 'Value': '11375158'}
# {'': '3834', 'Country Name': 'Belgium', 'Country Code': 'BEL', 'Year': '2018', 'Value': '11433256'}
# {'': '4248', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1960', 'Value': '72179226'}
# {'': '4249', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1961', 'Value': '74311343'}
# {'': '4250', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1962', 'Value': '76514328'}
# {'': '4251', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1963', 'Value': '78772657'}
# {'': '4252', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1964', 'Value': '81064571'}
# {'': '4253', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1965', 'Value': '83373530'}
# {'': '4254', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1966', 'Value': '85696505'}
# {'': '4255', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1967', 'Value': '88035814'}
# {'': '4256', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1968', 'Value': '90387079'}
# {'': '4257', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1969', 'Value': '92746614'}
# {'': '4258', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1970', 'Value': '95113265'}
# {'': '4259', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1971', 'Value': '97482920'}
# {'': '4260', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1972', 'Value': '99859383'}
# {'': '4261', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1973', 'Value': '102259497'}
# {'': '4262', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1974', 'Value': '104706198'}
# {'': '4263', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1975', 'Value': '107216205'}
# {'': '4264', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1976', 'Value': '109790938'}
# {'': '4265', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1977', 'Value': '112425392'}
# {'': '4266', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1978', 'Value': '115121153'}
# {'': '4267', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1979', 'Value': '117878411'}
# {'': '4268', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1980', 'Value': '120694009'}
# {'': '4269', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1981', 'Value': '123570327'}
# {'': '4270', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1982', 'Value': '126498314'}
# {'': '4271', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1983', 'Value': '129448819'}
# {'': '4272', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1984', 'Value': '132383568'}
# {'': '4273', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1985', 'Value': '135274080'}
# {'': '4274', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1986', 'Value': '138108912'}
# {'': '4275', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1987', 'Value': '140891602'}
# {'': '4276', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1988', 'Value': '143627503'}
# {'': '4277', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1989', 'Value': '146328304'}
# {'': '4278', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1990', 'Value': '149003223'}
# {'': '4279', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1991', 'Value': '151648011'}
# {'': '4280', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1992', 'Value': '154259380'}
# {'': '4281', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1993', 'Value': '156849078'}
# {'': '4282', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1994', 'Value': '159432716'}
# {'': '4283', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1995', 'Value': '162019896'}
# {'': '4284', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1996', 'Value': '164614688'}
# {'': '4285', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1997', 'Value': '167209040'}
# {'': '4286', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1998', 'Value': '169785250'}
# {'': '4287', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '1999', 'Value': '172318675'}
# {'': '4288', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2000', 'Value': '174790340'}
# {'': '4289', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2001', 'Value': '177196054'}
# {'': '4290', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2002', 'Value': '179537520'}
# {'': '4291', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2003', 'Value': '181809246'}
# {'': '4292', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2004', 'Value': '184006481'}
# {'': '4293', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2005', 'Value': '186127103'}
# {'': '4294', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2006', 'Value': '188167356'}
# {'': '4295', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2007', 'Value': '190130443'}
# {'': '4296', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2008', 'Value': '192030362'}
# {'': '4297', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2009', 'Value': '193886508'}
# {'': '4298', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2010', 'Value': '195713635'}
# {'': '4299', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2011', 'Value': '197514534'}
# {'': '4300', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2012', 'Value': '199287296'}
# {'': '4301', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2013', 'Value': '201035903'}
# {'': '4302', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2014', 'Value': '202763735'}
# {'': '4303', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2015', 'Value': '204471769'}
# {'': '4304', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2016', 'Value': '206163058'}
# {'': '4305', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2017', 'Value': '207833831'}
# {'': '4306', 'Country Name': 'Brazil', 'Country Code': 'BRA', 'Year': '2018', 'Value': '209469333'}
# {'': '5192', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1960', 'Value': '16057724'}
# {'': '5193', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1961', 'Value': '16567811'}
# {'': '5194', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1962', 'Value': '17092918'}
# {'': '5195', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1963', 'Value': '17629979'}
# {'': '5196', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1964', 'Value': '18175185'}
# {'': '5197', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1965', 'Value': '18725245'}
# {'': '5198', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1966', 'Value': '19279740'}
# {'': '5199', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1967', 'Value': '19837510'}
# {'': '5200', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1968', 'Value': '20393699'}
# {'': '5201', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1969', 'Value': '20942456'}
# {'': '5202', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1970', 'Value': '21480065'}
# {'': '5203', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1971', 'Value': '22003980'}
# {'': '5204', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1972', 'Value': '22516425'}
# {'': '5205', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1973', 'Value': '23024517'}
# {'': '5206', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1974', 'Value': '23538386'}
# {'': '5207', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1975', 'Value': '24065507'}
# {'': '5208', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1976', 'Value': '24608113'}
# {'': '5209', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1977', 'Value': '25164545'}
# {'': '5210', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1978', 'Value': '25733673'}
# {'': '5211', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1979', 'Value': '26312994'}
# {'': '5212', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1980', 'Value': '26900506'}
# {'': '5213', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1981', 'Value': '27496617'}
# {'': '5214', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1982', 'Value': '28101819'}
# {'': '5215', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1983', 'Value': '28714190'}
# {'': '5216', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1984', 'Value': '29331238'}
# {'': '5217', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1985', 'Value': '29951201'}
# {'': '5218', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1986', 'Value': '30572478'}
# {'': '5219', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1987', 'Value': '31195413'}
# {'': '5220', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1988', 'Value': '31822525'}
# {'': '5221', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1989', 'Value': '32457499'}
# {'': '5222', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1990', 'Value': '33102575'}
# {'': '5223', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1991', 'Value': '33758337'}
# {'': '5224', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1992', 'Value': '34422569'}
# {'': '5225', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1993', 'Value': '35091275'}
# {'': '5226', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1994', 'Value': '35758979'}
# {'': '5227', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1995', 'Value': '36421438'}
# {'': '5228', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1996', 'Value': '37076387'}
# {'': '5229', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1997', 'Value': '37723800'}
# {'': '5230', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1998', 'Value': '38364309'}
# {'': '5231', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '1999', 'Value': '38999471'}
# {'': '5232', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2000', 'Value': '39629968'}
# {'': '5233', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2001', 'Value': '40255967'}
# {'': '5234', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2002', 'Value': '40875360'}
# {'': '5235', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2003', 'Value': '41483869'}
# {'': '5236', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2004', 'Value': '42075955'}
# {'': '5237', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2005', 'Value': '42647723'}
# {'': '5238', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2006', 'Value': '43200897'}
# {'': '5239', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2007', 'Value': '43737516'}
# {'': '5240', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2008', 'Value': '44254975'}
# {'': '5241', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2009', 'Value': '44750054'}
# {'': '5242', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2010', 'Value': '45222700'}
# {'': '5243', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2011', 'Value': '45663099'}
# {'': '5244', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2012', 'Value': '46076848'}
# {'': '5245', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2013', 'Value': '46497267'}
# {'': '5246', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2014', 'Value': '46969209'}
# {'': '5247', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2015', 'Value': '47520667'}
# {'': '5248', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2016', 'Value': '48171392'}
# {'': '5249', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2017', 'Value': '48901066'}
# {'': '5250', 'Country Name': 'Colombia', 'Country Code': 'COL', 'Year': '2018', 'Value': '49648685'}
# {'': '5546', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1960', 'Value': '4140181'}
# {'': '5547', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1961', 'Value': '4167292'}
# {'': '5548', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1962', 'Value': '4196712'}
# {'': '5549', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1963', 'Value': '4225675'}
# {'': '5550', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1964', 'Value': '4252876'}
# {'': '5551', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1965', 'Value': '4280923'}
# {'': '5552', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1966', 'Value': '4310701'}
# {'': '5553', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1967', 'Value': '4338683'}
# {'': '5554', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1968', 'Value': '4365628'}
# {'': '5555', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1969', 'Value': '4391490'}
# {'': '5556', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1970', 'Value': '4412252'}
# {'': '5557', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1971', 'Value': '4431275'}
# {'': '5558', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1972', 'Value': '4450564'}
# {'': '5559', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1973', 'Value': '4470161'}
# {'': '5560', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1974', 'Value': '4490660'}
# {'': '5561', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1975', 'Value': '4512082'}
# {'': '5562', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1976', 'Value': '4535934'}
# {'': '5563', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1977', 'Value': '4559571'}
# {'': '5564', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1978', 'Value': '4581085'}
# {'': '5565', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1979', 'Value': '4594778'}
# {'': '5566', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1980', 'Value': '4599782'}
# {'': '5567', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1981', 'Value': '4611509'}
# {'': '5568', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1982', 'Value': '4634234'}
# {'': '5569', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1983', 'Value': '4658254'}
# {'': '5570', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1984', 'Value': '4680285'}
# {'': '5571', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1985', 'Value': '4701417'}
# {'': '5572', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1986', 'Value': '4721446'}
# {'': '5573', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1987', 'Value': '4739745'}
# {'': '5574', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1988', 'Value': '4755207'}
# {'': '5575', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1989', 'Value': '4767260'}
# {'': '5576', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1990', 'Value': '4777368'}
# {'': '5577', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1991', 'Value': '4689022'}
# {'': '5578', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1992', 'Value': '4575818'}
# {'': '5579', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1993', 'Value': '4600463'}
# {'': '5580', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1994', 'Value': '4652024'}
# {'': '5581', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1995', 'Value': '4620030'}
# {'': '5582', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1996', 'Value': '4557097'}
# {'': '5583', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1997', 'Value': '4534920'}
# {'': '5584', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1998', 'Value': '4532135'}
# {'': '5585', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '1999', 'Value': '4512597'}
# {'': '5586', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2000', 'Value': '4468302'}
# {'': '5587', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2001', 'Value': '4299642'}
# {'': '5588', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2002', 'Value': '4302174'}
# {'': '5589', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2003', 'Value': '4303399'}
# {'': '5590', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2004', 'Value': '4304600'}
# {'': '5591', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2005', 'Value': '4310145'}
# {'': '5592', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2006', 'Value': '4311159'}
# {'': '5593', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2007', 'Value': '4310217'}
# {'': '5594', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2008', 'Value': '4309705'}
# {'': '5595', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2009', 'Value': '4305181'}
# {'': '5596', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2010', 'Value': '4295427'}
# {'': '5597', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2011', 'Value': '4280622'}
# {'': '5598', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2012', 'Value': '4267558'}
# {'': '5599', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2013', 'Value': '4255689'}
# {'': '5600', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2014', 'Value': '4238389'}
# {'': '5601', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2015', 'Value': '4203604'}
# {'': '5602', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2016', 'Value': '4174349'}
# {'': '5603', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2017', 'Value': '4124531'}
# {'': '5604', 'Country Name': 'Croatia', 'Country Code': 'HRV', 'Year': '2018', 'Value': '4087843'}
# {'': '5841', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1960', 'Value': '4579603'}
# {'': '5842', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1961', 'Value': '4611687'}
# {'': '5843', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1962', 'Value': '4647727'}
# {'': '5844', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1963', 'Value': '4684483'}
# {'': '5845', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1964', 'Value': '4722072'}
# {'': '5846', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1965', 'Value': '4759012'}
# {'': '5847', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1966', 'Value': '4797381'}
# {'': '5848', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1967', 'Value': '4835354'}
# {'': '5849', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1968', 'Value': '4864883'}
# {'': '5850', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1969', 'Value': '4891860'}
# {'': '5851', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1970', 'Value': '4928757'}
# {'': '5852', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1971', 'Value': '4963126'}
# {'': '5853', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1972', 'Value': '4991596'}
# {'': '5854', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1973', 'Value': '5021861'}
# {'': '5855', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1974', 'Value': '5045297'}
# {'': '5856', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1975', 'Value': '5059862'}
# {'': '5857', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1976', 'Value': '5072596'}
# {'': '5858', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1977', 'Value': '5088419'}
# {'': '5859', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1978', 'Value': '5104248'}
# {'': '5860', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1979', 'Value': '5116801'}
# {'': '5861', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1980', 'Value': '5123027'}
# {'': '5862', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1981', 'Value': '5121572'}
# {'': '5863', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1982', 'Value': '5117810'}
# {'': '5864', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1983', 'Value': '5114297'}
# {'': '5865', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1984', 'Value': '5111619'}
# {'': '5866', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1985', 'Value': '5113691'}
# {'': '5867', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1986', 'Value': '5120534'}
# {'': '5868', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1987', 'Value': '5127024'}
# {'': '5869', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1988', 'Value': '5129516'}
# {'': '5870', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1989', 'Value': '5132594'}
# {'': '5871', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1990', 'Value': '5140939'}
# {'': '5872', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1991', 'Value': '5154298'}
# {'': '5873', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1992', 'Value': '5171370'}
# {'': '5874', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1993', 'Value': '5188628'}
# {'': '5875', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1994', 'Value': '5206180'}
# {'': '5876', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1995', 'Value': '5233373'}
# {'': '5877', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1996', 'Value': '5263074'}
# {'': '5878', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1997', 'Value': '5284991'}
# {'': '5879', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1998', 'Value': '5304219'}
# {'': '5880', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '1999', 'Value': '5321799'}
# {'': '5881', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2000', 'Value': '5339616'}
# {'': '5882', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2001', 'Value': '5358783'}
# {'': '5883', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2002', 'Value': '5375931'}
# {'': '5884', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2003', 'Value': '5390574'}
# {'': '5885', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2004', 'Value': '5404523'}
# {'': '5886', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2005', 'Value': '5419432'}
# {'': '5887', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2006', 'Value': '5437272'}
# {'': '5888', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2007', 'Value': '5461438'}
# {'': '5889', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2008', 'Value': '5493621'}
# {'': '5890', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2009', 'Value': '5523095'}
# {'': '5891', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2010', 'Value': '5547683'}
# {'': '5892', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2011', 'Value': '5570572'}
# {'': '5893', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2012', 'Value': '5591572'}
# {'': '5894', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2013', 'Value': '5614932'}
# {'': '5895', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2014', 'Value': '5643475'}
# {'': '5896', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2015', 'Value': '5683483'}
# {'': '5897', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2016', 'Value': '5728010'}
# {'': '5898', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2017', 'Value': '5764980'}
# {'': '5899', 'Country Name': 'Denmark', 'Country Code': 'DNK', 'Year': '2018', 'Value': '5793636'}
# {'': '6719', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1960', 'Value': '46621669'}
# {'': '6720', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1961', 'Value': '47240543'}
# {'': '6721', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1962', 'Value': '47904877'}
# {'': '6722', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1963', 'Value': '48582611'}
# {'': '6723', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1964', 'Value': '49230595'}
# {'': '6724', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1965', 'Value': '49818028'}
# {'': '6725', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1966', 'Value': '50330262'}
# {'': '6726', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1967', 'Value': '50775794'}
# {'': '6727', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1968', 'Value': '51175508'}
# {'': '6728', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1969', 'Value': '51561836'}
# {'': '6729', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1970', 'Value': '51957738'}
# {'': '6730', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1971', 'Value': '52371342'}
# {'': '6731', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1972', 'Value': '52793138'}
# {'': '6732', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1973', 'Value': '53207734'}
# {'': '6733', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1974', 'Value': '53592233'}
# {'': '6734', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1975', 'Value': '53931390'}
# {'': '6735', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1976', 'Value': '54220022'}
# {'': '6736', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1977', 'Value': '54467702'}
# {'': '6737', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1978', 'Value': '54691851'}
# {'': '6738', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1979', 'Value': '54917118'}
# {'': '6739', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1980', 'Value': '55161527'}
# {'': '6740', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1981', 'Value': '55430296'}
# {'': '6741', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1982', 'Value': '55718933'}
# {'': '6742', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1983', 'Value': '56023770'}
# {'': '6743', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1984', 'Value': '56337666'}
# {'': '6744', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1985', 'Value': '56654696'}
# {'': '6745', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1986', 'Value': '56976123'}
# {'': '6746', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1987', 'Value': '57302663'}
# {'': '6747', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1988', 'Value': '57627105'}
# {'': '6748', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1989', 'Value': '57940212'}
# {'': '6749', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1990', 'Value': '58235697'}
# {'': '6750', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1991', 'Value': '58559311'}
# {'': '6751', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1992', 'Value': '58851217'}
# {'': '6752', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1993', 'Value': '59106768'}
# {'': '6753', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1994', 'Value': '59327192'}
# {'': '6754', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1995', 'Value': '59541899'}
# {'': '6755', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1996', 'Value': '59753100'}
# {'': '6756', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1997', 'Value': '59964851'}
# {'': '6757', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1998', 'Value': '60186288'}
# {'': '6758', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '1999', 'Value': '60496718'}
# {'': '6759', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2000', 'Value': '60912500'}
# {'': '6760', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2001', 'Value': '61357430'}
# {'': '6761', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2002', 'Value': '61805267'}
# {'': '6762', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2003', 'Value': '62244886'}
# {'': '6763', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2004', 'Value': '62704895'}
# {'': '6764', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2005', 'Value': '63179351'}
# {'': '6765', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2006', 'Value': '63621381'}
# {'': '6766', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2007', 'Value': '64016225'}
# {'': '6767', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2008', 'Value': '64374984'}
# {'': '6768', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2009', 'Value': '64707040'}
# {'': '6769', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2010', 'Value': '65027507'}
# {'': '6770', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2011', 'Value': '65342780'}
# {'': '6771', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2012', 'Value': '65659809'}
# {'': '6772', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2013', 'Value': '65998687'}
# {'': '6773', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2014', 'Value': '66312067'}
# {'': '6774', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2015', 'Value': '66548272'}
# {'': '6775', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2016', 'Value': '66721256'}
# {'': '6776', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2017', 'Value': '66865144'}
# {'': '6777', 'Country Name': 'France', 'Country Code': 'FRA', 'Year': '2018', 'Value': '66977107'}
# {'': '7014', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1960', 'Value': '72814900'}
# {'': '7015', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1961', 'Value': '73377632'}
# {'': '7016', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1962', 'Value': '74025784'}
# {'': '7017', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1963', 'Value': '74714353'}
# {'': '7018', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1964', 'Value': '75318337'}
# {'': '7019', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1965', 'Value': '75963695'}
# {'': '7020', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1966', 'Value': '76600311'}
# {'': '7021', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1967', 'Value': '76951336'}
# {'': '7022', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1968', 'Value': '77294314'}
# {'': '7023', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1969', 'Value': '77909682'}
# {'': '7024', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1970', 'Value': '78169289'}
# {'': '7025', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1971', 'Value': '78312842'}
# {'': '7026', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1972', 'Value': '78688452'}
# {'': '7027', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1973', 'Value': '78936666'}
# {'': '7028', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1974', 'Value': '78967433'}
# {'': '7029', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1975', 'Value': '78673554'}
# {'': '7030', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1976', 'Value': '78336950'}
# {'': '7031', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1977', 'Value': '78159814'}
# {'': '7032', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1978', 'Value': '78091820'}
# {'': '7033', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1979', 'Value': '78126350'}
# {'': '7034', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1980', 'Value': '78288576'}
# {'': '7035', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1981', 'Value': '78407907'}
# {'': '7036', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1982', 'Value': '78333366'}
# {'': '7037', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1983', 'Value': '78128282'}
# {'': '7038', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1984', 'Value': '77858685'}
# {'': '7039', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1985', 'Value': '77684873'}
# {'': '7040', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1986', 'Value': '77720436'}
# {'': '7041', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1987', 'Value': '77839920'}
# {'': '7042', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1988', 'Value': '78144619'}
# {'': '7043', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1989', 'Value': '78751283'}
# {'': '7044', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1990', 'Value': '79433029'}
# {'': '7045', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1991', 'Value': '80013896'}
# {'': '7046', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1992', 'Value': '80624598'}
# {'': '7047', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1993', 'Value': '81156363'}
# {'': '7048', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1994', 'Value': '81438348'}
# {'': '7049', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1995', 'Value': '81678051'}
# {'': '7050', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1996', 'Value': '81914831'}
# {'': '7051', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1997', 'Value': '82034771'}
# {'': '7052', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1998', 'Value': '82047195'}
# {'': '7053', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '1999', 'Value': '82100243'}
# {'': '7054', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2000', 'Value': '82211508'}
# {'': '7055', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2001', 'Value': '82349925'}
# {'': '7056', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2002', 'Value': '82488495'}
# {'': '7057', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2003', 'Value': '82534176'}
# {'': '7058', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2004', 'Value': '82516260'}
# {'': '7059', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2005', 'Value': '82469422'}
# {'': '7060', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2006', 'Value': '82376451'}
# {'': '7061', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2007', 'Value': '82266372'}
# {'': '7062', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2008', 'Value': '82110097'}
# {'': '7063', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2009', 'Value': '81902307'}
# {'': '7064', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2010', 'Value': '81776930'}
# {'': '7065', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2011', 'Value': '80274983'}
# {'': '7066', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2012', 'Value': '80425823'}
# {'': '7067', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2013', 'Value': '80645605'}
# {'': '7068', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2014', 'Value': '80982500'}
# {'': '7069', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2015', 'Value': '81686611'}
# {'': '7070', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2016', 'Value': '82348669'}
# {'': '7071', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2017', 'Value': '82657002'}
# {'': '7072', 'Country Name': 'Germany', 'Country Code': 'DEU', 'Year': '2018', 'Value': '82905782'}
# {'': '8076', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1960', 'Value': '21906914'}
# {'': '8077', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1961', 'Value': '22480372'}
# {'': '8078', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1962', 'Value': '23071315'}
# {'': '8079', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1963', 'Value': '23680258'}
# {'': '8080', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1964', 'Value': '24307860'}
# {'': '8081', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1965', 'Value': '24954873'}
# {'': '8082', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1966', 'Value': '25624373'}
# {'': '8083', 'Country Name': 'Iran', 'Country Code': 'IRN', 'Year': '1967', 'Value': '26317783'}
# ...
# {'': '14278', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1979', 'Value': '6210756'}
# {'': '14279', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1980', 'Value': '6374039'}
# {'': '14280', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1981', 'Value': '6551231'}
# {'': '14281', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1982', 'Value': '6740529'}
# {'': '14282', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1983', 'Value': '6937331'}
# {'': '14283', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1984', 'Value': '7135270'}
# {'': '14284', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1985', 'Value': '7329594'}
# {'': '14285', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1986', 'Value': '7517858'}
# {'': '14286', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1987', 'Value': '7700736'}
# {'': '14287', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1988', 'Value': '7880332'}
# {'': '14288', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1989', 'Value': '8060210'}
# {'': '14289', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1990', 'Value': '8242496'}
# {'': '14290', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1991', 'Value': '8427857'}
# {'': '14291', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1992', 'Value': '8613861'}
# {'': '14292', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1993', 'Value': '8795932'}
# {'': '14293', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1994', 'Value': '8967916'}
# {'': '14294', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1995', 'Value': '9125398'}
# {'': '14295', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1996', 'Value': '9267340'}
# {'': '14296', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1997', 'Value': '9395123'}
# {'': '14297', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1998', 'Value': '9509857'}
# {'': '14298', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '1999', 'Value': '9613588'}
# {'': '14299', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2000', 'Value': '9708350'}
# {'': '14300', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2001', 'Value': '9793903'}
# {'': '14301', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2002', 'Value': '9871251'}
# {'': '14302', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2003', 'Value': '9945277'}
# {'': '14303', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2004', 'Value': '10022277'}
# {'': '14304', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2005', 'Value': '10106771'}
# {'': '14305', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2006', 'Value': '10201214'}
# {'': '14306', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2007', 'Value': '10304726'}
# {'': '14307', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2008', 'Value': '10414433'}
# {'': '14308', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2009', 'Value': '10525694'}
# {'': '14309', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2010', 'Value': '10635244'}
# {'': '14310', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2011', 'Value': '10741880'}
# {'': '14311', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2012', 'Value': '10847002'}
# {'': '14312', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2013', 'Value': '10952951'}
# {'': '14313', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2014', 'Value': '11063201'}
# {'': '14314', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2015', 'Value': '11179949'}
# {'': '14315', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2016', 'Value': '11303946'}
# {'': '14316', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2017', 'Value': '11433443'}
# {'': '14317', 'Country Name': 'Tunisia', 'Country Code': 'TUN', 'Year': '2018', 'Value': '11565204'}
# {'': '14731', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1960', 'Value': '52400000'}
# {'': '14732', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1961', 'Value': '52800000'}
# {'': '14733', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1962', 'Value': '53250000'}
# {'': '14734', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1963', 'Value': '53650000'}
# {'': '14735', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1964', 'Value': '54000000'}
# {'': '14736', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1965', 'Value': '54348050'}
# {'': '14737', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1966', 'Value': '54648500'}
# {'': '14738', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1967', 'Value': '54943600'}
# {'': '14739', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1968', 'Value': '55211700'}
# {'': '14740', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1969', 'Value': '55441750'}
# {'': '14741', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1970', 'Value': '55663250'}
# {'': '14742', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1971', 'Value': '55896223'}
# {'': '14743', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1972', 'Value': '56086065'}
# {'': '14744', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1973', 'Value': '56194527'}
# {'': '14745', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1974', 'Value': '56229974'}
# {'': '14746', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1975', 'Value': '56225800'}
# {'': '14747', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1976', 'Value': '56211968'}
# {'': '14748', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1977', 'Value': '56193492'}
# {'': '14749', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1978', 'Value': '56196504'}
# {'': '14750', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1979', 'Value': '56246951'}
# {'': '14751', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1980', 'Value': '56314216'}
# {'': '14752', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1981', 'Value': '56333829'}
# {'': '14753', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1982', 'Value': '56313641'}
# {'': '14754', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1983', 'Value': '56332848'}
# {'': '14755', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1984', 'Value': '56422072'}
# {'': '14756', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1985', 'Value': '56550268'}
# {'': '14757', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1986', 'Value': '56681396'}
# {'': '14758', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1987', 'Value': '56802050'}
# {'': '14759', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1988', 'Value': '56928327'}
# {'': '14760', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1989', 'Value': '57076711'}
# {'': '14761', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1990', 'Value': '57247586'}
# {'': '14762', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1991', 'Value': '57424897'}
# {'': '14763', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1992', 'Value': '57580402'}
# {'': '14764', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1993', 'Value': '57718614'}
# {'': '14765', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1994', 'Value': '57865745'}
# {'': '14766', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1995', 'Value': '58019030'}
# {'': '14767', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1996', 'Value': '58166950'}
# {'': '14768', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1997', 'Value': '58316954'}
# {'': '14769', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1998', 'Value': '58487141'}
# {'': '14770', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '1999', 'Value': '58682466'}
# {'': '14771', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2000', 'Value': '58892514'}
# {'': '14772', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2001', 'Value': '59119673'}
# {'': '14773', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2002', 'Value': '59370479'}
# {'': '14774', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2003', 'Value': '59647577'}
# {'': '14775', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2004', 'Value': '59987905'}
# {'': '14776', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2005', 'Value': '60401206'}
# {'': '14777', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2006', 'Value': '60846820'}
# {'': '14778', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2007', 'Value': '61322463'}
# {'': '14779', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2008', 'Value': '61806995'}
# {'': '14780', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2009', 'Value': '62276270'}
# {'': '14781', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2010', 'Value': '62766365'}
# {'': '14782', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2011', 'Value': '63258810'}
# {'': '14783', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2012', 'Value': '63700215'}
# {'': '14784', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2013', 'Value': '64128273'}
# {'': '14785', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2014', 'Value': '64602298'}
# {'': '14786', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2015', 'Value': '65116219'}
# {'': '14787', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2016', 'Value': '65611593'}
# {'': '14788', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2017', 'Value': '66058859'}
# {'': '14789', 'Country Name': 'England', 'Country Code': 'GBR', 'Year': '2018', 'Value': '66460344'}
# {'': '14849', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1960', 'Value': '2538643'}
# {'': '14850', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1961', 'Value': '2571681'}
# {'': '14851', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1962', 'Value': '2603882'}
# {'': '14852', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1963', 'Value': '2635126'}
# {'': '14853', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1964', 'Value': '2665388'}
# {'': '14854', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1965', 'Value': '2694536'}
# {'': '14855', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1966', 'Value': '2722875'}
# {'': '14856', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1967', 'Value': '2750086'}
# {'': '14857', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1968', 'Value': '2774759'}
# {'': '14858', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1969', 'Value': '2795042'}
# {'': '14859', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1970', 'Value': '2809793'}
# {'': '14860', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1971', 'Value': '2818281'}
# {'': '14861', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1972', 'Value': '2821461'}
# {'': '14862', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1973', 'Value': '2822117'}
# {'': '14863', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1974', 'Value': '2824095'}
# {'': '14864', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1975', 'Value': '2830176'}
# {'': '14865', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1976', 'Value': '2841372'}
# {'': '14866', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1977', 'Value': '2856958'}
# {'': '14867', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1978', 'Value': '2875728'}
# {'': '14868', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1979', 'Value': '2895688'}
# {'': '14869', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1980', 'Value': '2915389'}
# {'': '14870', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1981', 'Value': '2934613'}
# {'': '14871', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1982', 'Value': '2953852'}
# {'': '14872', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1983', 'Value': '2973036'}
# {'': '14873', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1984', 'Value': '2992246'}
# {'': '14874', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1985', 'Value': '3011519'}
# {'': '14875', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1986', 'Value': '3030649'}
# {'': '14876', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1987', 'Value': '3049581'}
# {'': '14877', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1988', 'Value': '3068705'}
# {'': '14878', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1989', 'Value': '3088595'}
# {'': '14879', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1990', 'Value': '3109601'}
# {'': '14880', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1991', 'Value': '3131660'}
# {'': '14881', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1992', 'Value': '3154464'}
# {'': '14882', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1993', 'Value': '3177745'}
# {'': '14883', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1994', 'Value': '3201151'}
# {'': '14884', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1995', 'Value': '3224281'}
# {'': '14885', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1996', 'Value': '3247381'}
# {'': '14886', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1997', 'Value': '3270164'}
# {'': '14887', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1998', 'Value': '3291053'}
# {'': '14888', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '1999', 'Value': '3308012'}
# {'': '14889', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2000', 'Value': '3319736'}
# {'': '14890', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2001', 'Value': '3325473'}
# {'': '14891', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2002', 'Value': '3326040'}
# {'': '14892', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2003', 'Value': '3323668'}
# {'': '14893', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2004', 'Value': '3321476'}
# {'': '14894', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2005', 'Value': '3321803'}
# {'': '14895', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2006', 'Value': '3325401'}
# {'': '14896', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2007', 'Value': '3331749'}
# {'': '14897', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2008', 'Value': '3340221'}
# {'': '14898', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2009', 'Value': '3349676'}
# {'': '14899', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2010', 'Value': '3359275'}
# {'': '14900', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2011', 'Value': '3368934'}
# {'': '14901', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2012', 'Value': '3378974'}
# {'': '14902', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2013', 'Value': '3389439'}
# {'': '14903', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2014', 'Value': '3400434'}
# {'': '14904', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2015', 'Value': '3412009'}
# {'': '14905', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2016', 'Value': '3424132'}
# {'': '14906', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2017', 'Value': '3436646'}
# {'': '14907', 'Country Name': 'Uruguay', 'Country Code': 'URY', 'Year': '2018', 'Value': '3449299'}
# {'': '14907',
#  'Country Name': 'Uruguay',
#  'Country Code': 'URY',
#  'Year': '2018',
#  'Value': 3449299}

# %% [markdown]
# Check that it worked with the assert statement below:

# %%
# Run this cell without changes
assert type(population_data_filtered[-1]["Value"]) == int

# %% [markdown]
# ### Adding Population Data
#
# Now it's time to add the population data to `combined_data`. Recall that the data structure currently looks like this:

# %%
# Run this cell without changes
combined_data
# Out:
# {'Russia': {'wins': 2},
#  'Uruguay': {'wins': 4},
#  'Iran': {'wins': 1},
#  'France': {'wins': 6},
#  'Denmark': {'wins': 1},
#  'Croatia': {'wins': 3},
#  'Serbia': {'wins': 1},
#  'Mexico': {'wins': 2},
#  'Sweden': {'wins': 3},
#  'Belgium': {'wins': 6},
#  'England': {'wins': 3},
#  'Senegal': {'wins': 1},
#  'Japan': {'wins': 1},
#  'Portugal': {'wins': 1},
#  'Spain': {'wins': 1},
#  'Nigeria': {'wins': 1},
#  'Brazil': {'wins': 3},
#  'Switzerland': {'wins': 1},
#  'Germany': {'wins': 1},
#  'Colombia': {'wins': 2},
#  'Saudi Arabia': {'wins': 1},
#  'Peru': {'wins': 1},
#  'Argentina': {'wins': 1},
#  'South Korea': {'wins': 1},
#  'Tunisia': {'wins': 1},
#  'Poland': {'wins': 1}}

# %% [markdown]
# The goal is for it to be structured like this:
# ```
# {
#   'Argentina': { 'wins': 1, 'population': 44494502 },
#   ...
#   'Uruguay':   { 'wins': 4, 'population': 3449299  }
# }
# ```

# %% [markdown]
# In the cell below, loop over `population_data_filtered` and add information about population to each country in `combined_data`:

# %%
# Replace None with appropriate code
for record in population_data_filtered:
    # Extract the country name from the record
    country = record["Country Name"]
    # Extract the population value from the record
    population = record['Value']
    # Add this information to combined_data
    if country in combined_data:
        combined_data[country]['population'] = population

# Look combined_data
combined_data
# Out:
# {'Russia': {'wins': 2, 'population': 144478050},
#  'Uruguay': {'wins': 4, 'population': 3449299},
#  'Iran': {'wins': 1, 'population': 81800269},
#  'France': {'wins': 6, 'population': 66977107},
#  'Denmark': {'wins': 1, 'population': 5793636},
#  'Croatia': {'wins': 3, 'population': 4087843},
#  'Serbia': {'wins': 1, 'population': 6982604},
#  'Mexico': {'wins': 2, 'population': 126190788},
#  'Sweden': {'wins': 3, 'population': 10175214},
#  'Belgium': {'wins': 6, 'population': 11433256},
#  'England': {'wins': 3, 'population': 66460344},
#  'Senegal': {'wins': 1, 'population': 15854360},
#  'Japan': {'wins': 1, 'population': 126529100},
#  'Portugal': {'wins': 1, 'population': 10283822},
#  'Spain': {'wins': 1, 'population': 46796540},
#  'Nigeria': {'wins': 1, 'population': 195874740},
#  'Brazil': {'wins': 3, 'population': 209469333},
#  'Switzerland': {'wins': 1, 'population': 8513227},
#  'Germany': {'wins': 1, 'population': 82905782},
#  'Colombia': {'wins': 2, 'population': 49648685},
#  'Saudi Arabia': {'wins': 1, 'population': 33699947},
#  'Peru': {'wins': 1, 'population': 31989256},
#  'Argentina': {'wins': 1, 'population': 44494502},
#  'South Korea': {'wins': 1, 'population': 51606633},
#  'Tunisia': {'wins': 1, 'population': 11565204},
#  'Poland': {'wins': 1, 'population': 37974750}}

# %% [markdown]
# Check that the types are correct with these assert statements:

# %%
# Run this cell without changes
assert type(combined_data["Uruguay"]) == dict
assert type(combined_data["Uruguay"]["population"]) == int

# %% [markdown]
# ### Analysis of Population
#
# Let's perform the same analysis for population that we performed for count of wins.
#
# #### Statistical Analysis of Population

# %%
# Run this cell without changes
populations = [val["population"] for val in combined_data.values()]

print("Mean population:", np.mean(populations))
print("Median population:", np.median(populations))
print("Standard deviation of population:", np.std(populations))
# Out:
# Mean population: 57116703.5
# Median population: 41234626.0
# Standard deviation of population: 57681744.85841965

# %% [markdown]
# #### Visualizations of Population

# %%
# Run this cell without changes

# Set up figure and axes
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 7))
fig.set_tight_layout(True)

# Histogram of Populations and Frequencies
ax1.hist(x=populations, color="blue")
ax1.set_xlabel("2018 Population")
ax1.set_ylabel("Frequency")
ax1.set_title("Distribution of Population")

# Horizontal Bar Graph of Population by Country
ax2.barh(teams[::-1], populations[::-1], color="blue")
ax2.set_xlabel("2018 Population")
ax2.set_title("Population by Country");

# %% [markdown]
# #### Interpretation of Population Analysis
#
# * Similar to the distribution of the number of wins, the distribution of population is skewed.
# * It's hard to choose a single "typical" value here because there is so much variation.
# * The countries with the largest populations (Brazil, Nigeria, and Russia) do not overlap with the countries with the most wins (Belgium, France, and Uruguay)

# %% [markdown]
# ## 4. Analysis of Population vs. Performance
#
# > Choose an appropriate statistical measure to analyze the relationship between population and performance, and create a visualization representing this relationship.
#
# ### Statistical Measure
# So far we have learned about only two statistics for understanding the *relationship* between variables: **covariance** and **correlation**. We will use correlation here, because that provides a more standardized, interpretable metric.

# %%
# Run this cell without changes
np.corrcoef(wins, populations)[0][1]
# Out:
# -0.030800325223370742

# %% [markdown]
# In the cell below, interpret this number. What direction is this correlation? Is it strong or weak?

# %%
# Replace None with appropriate code
"""
correlation of 0.03 means indicates a very weak negative relationship between population size 
and the number of wins. 
"""
# Out:
# '\ncorrelation of 0.03 means indicates a very weak negative relationship between population size \nand the number of wins. \n'

# %% [markdown]
# ### Data Visualization
#
# A **scatter plot** is he most sensible form of data visualization for showing this relationship, because we have two dimensions of data, but there is no "increasing" variable (e.g. time) that would indicate we should use a line graph.

# %%
# Run this cell without changes

# Set up figure
fig, ax = plt.subplots(figsize=(8, 5))

# Basic scatter plot
ax.scatter(x=populations, y=wins, color="gray", alpha=0.5, s=100)
ax.set_xlabel("2018 Population")
ax.set_ylabel("2018 World Cup Wins")
ax.set_title("Population vs. World Cup Wins")

# Add annotations for specific points of interest
highlighted_points = {
    "Belgium": 2,  # Numbers are the index of that
    "Brazil": 3,  # country in populations & wins
    "France": 10,
    "Nigeria": 17,
}
for country, index in highlighted_points.items():
    # Get x and y position of data point
    x = populations[index]
    y = wins[index]
    # Move each point slightly down and to the left
    # (numbers were chosen by manually tweaking)
    xtext = x - (1.25e6 * len(country))
    ytext = y - 0.5
    # Annotate with relevant arguments
    ax.annotate(text=country, xy=(x, y), xytext=(xtext, ytext))

# %% [markdown]
# ### Data Visualization Interpretation
#
# Interpret this plot in the cell below. Does this align with the findings from the statistical measure (correlation), as well as the map shown at the beginning of this lab (showing the best results by country)?

# %%
# Replace None with appropriate text
"""
Points are widely scattered without a clear identifiable pattern
"""
# Out:
# '\nPoints are widely scattered without a clear identifiable pattern\n'

# %% [markdown]
# ### Final Analysis
#
# > What is the relationship between the population of a country and their performance in the 2018 FIFA World Cup?
#
# Overall, we found a very weakly positive relationship between the population of a country and their performance in the 2018 FIFA World Cup, as demonstrated by both the correlation between populations and wins, and the scatter plot.
#
# In the cell below, write down your thoughts on these questions:
#
#  - What are your thoughts on why you may see this result?
#  - What would you research next?

# %%
# Replace None with appropriate text
"""
The weak positive correlation of 0.03 between the population of a country and its performance 
in the 2018 FIFA World Cup suggests that there isn't a strong connection between the two factors. 
A few possible reasons for this weak relationship could be:
- Success in the World Cup is more about the quality of the national football team, including the skill level 
of players, coaching, and resources for training, rather than just the number of people in the country. 
"""
# Out:
# "\nThe weak positive correlation of 0.03 between the population of a country and its performance \nin the 2018 FIFA World Cup suggests that there isn't a strong connection between the two factors. \nA few possible reasons for this weak relationship could be:\n- Success in the World Cup is more about the quality of the national football team, including the skill level \nof players, coaching, and resources for training, rather than just the number of people in the country. \n"

# %% [markdown]
# ## Summary
#
# That was a long lab, pulling together a lot of material. You read data into Python, extracted the relevant information, cleaned the data, and combined the data into a new format to be used in analysis. While we will continue to introduce new tools and techniques, these essential steps will be present for the rest of your data science projects from here on out.
